# %%
salary_df = pd.read_csv('20-21salaries.csv')
# Out:
# /Users/eunicepark/opt/anaconda3/envs/myenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
salary_df
# Out:
#                                                      GID  \
# 0                                                   5679
# 1                                                   5679
# 2                                                   5679
# 3                                                   5679
# 4                                                   5679
# ...                                                  ...
# 38766  A comparable file for the 2019-20 NBA season i...
# 38767  A comparable file for the 2018-19 NBA season i...
# 38768  A comparable file for the 2017-18 NBA season i...
# 38769  A comparable file for the 2016-17 NBA season i...
# 38770  A comparable file for the 2015-16 NBA season i...
#
#                                    Last, First   First  Last        Date Team  \
# 0                                Eubanks, Drew  Drew Eubanks  20210519.0  sas
# 1                                Eubanks, Drew  Drew Eubanks  20210516.0  sas
# ...

# %%
salary_df.columns.values
# Out:
# array(['GID', 'Last, First', 'First  Last', 'Date', 'Team', 'Opp', 'H/A',
#        'GameID', 'GTime(ET)', 'Team pts', 'Opp pts', 'Start', 'Minutes',
#        'GP', 'active', 'FDP', 'DKP', 'DDP', 'YHP', 'Stats', 'DoubleD',
#        'TripleD', 'FD Sal', 'FD Change', 'DK Sal', 'DK Change', 'DD Sal',
#        'DD Change', 'YH Sal', 'YH Change', 'FD pos', 'DK pos', 'DD pos',
#        'YH pos', 'ADI', 'VMI'], dtype=object)

# %%
salary_df_clean = salary_df.dropna(subset=['DK Sal'])

# %%
df = salary_df_clean

# %%
df['Date'] = df['Date'].apply(lambda x: int(x) if x == x else x)
df['Date'] = pd.to_datetime(df['Date'], format='%Y%m%d', errors='coerce')
# Out:
# /Users/eunicepark/opt/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/eunicepark/opt/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#         GID           Last, First          First  Last       Date Team  Opp  \
# 0      5679         Eubanks, Drew         Drew Eubanks 2021-05-19  sas  mem
# 1      5679         Eubanks, Drew         Drew Eubanks 2021-05-16  sas  pho
# 2      5679         Eubanks, Drew         Drew Eubanks 2021-05-15  sas  pho
# 3      5679         Eubanks, Drew         Drew Eubanks 2021-05-13  sas  nyk
# 4      5679         Eubanks, Drew         Drew Eubanks 2021-05-12  sas  bkn
# ...     ...                   ...                  ...        ...  ...  ...
# 38759  4817  Cauley-Stein, Willie  Willie Cauley-Stein 2021-01-03  dal  chi
# 38760  4817  Cauley-Stein, Willie  Willie Cauley-Stein 2021-01-01  dal  mia
# 38761  4817  Cauley-Stein, Willie  Willie Cauley-Stein 2020-12-30  dal  cha
# 38763  4817  Cauley-Stein, Willie  Willie Cauley-Stein 2020-12-25  dal  lal
# 38764  4817  Cauley-Stein, Willie  Willie Cauley-Stein 2020-12-23  dal  pho
#
# ...

# %%
df.to_csv('salary.csv')

# %% [markdown]
# ### additional links for salary to check: https://swishanalytics.com/optimus/nba/fanduel-draftkings-live-scoring?date=2023-04-18
